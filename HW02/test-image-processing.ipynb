# %%
from matplotlib import pyplot as plt
import cv2

img = cv2.imread(r'C:\Users\WINDOWS 10\Pictures\Saved Pictures\1637079906636_khunghinh.net.png')

plt.imshow(img)
print("Cao %d pixel, rong: %d pixel, %d kenh mau." % (img.shape[0], img.shape[1], img.shape[2]))
# Out:
# Cao 700 pixel, rong: 700 pixel, 3 kenh mau.

# %%
import cv2
# Đọc ảnh đầu vào với tên là pandas.png
# Kết quả trả về lưu vào biến img kiểu numpy.array
img = cv2.imread(r'C:\Users\WINDOWS 10\Pictures\Saved Pictures\1637079906636_khunghinh.net.png', 0)

plt.imshow(img)

# %%
import cv2
# Đọc ảnh đầu vào với tên là pandas.png
# Kết quả trả về lưu vào biến img kiểu numpy.array
img = cv2.imread(r'C:\Users\WINDOWS 10\Pictures\Saved Pictures\1637079906636_khunghinh.net.png')
# Thực hiện biến đổi trên ma trận img
...
# Hàm imwrite hỗ trợ lưu các định dạng phổ biến như bmp, png, jpeg
# cv2.imwrite(r'C:\Users\WINDOWS 10\Pictures', img)

# %%
import cv2
# Đọc ảnh đầu vào với tên là pandas.png
# Kết quả trả về lưu vào biến img kiểu numpy.array
img = cv2.imread(r'C:\Users\WINDOWS 10\Pictures\Saved Pictures\1637079906636_khunghinh.net.png')
# Thực hiện biến đổi trên ma trận img
...
# Hàm cv2.imshow để hiển thị ảnh
# Tham số đầu tiên là tên cửa sổ để hiển thị ảnh
# Tham số thứ hai là ma trận ảnh
cv2.imshow('Panda image', img)

# %%
import numpy as np

# %%
img = cv2.imread(r'C:\Users\WINDOWS 10\Pictures\Saved Pictures\1637079906636_khunghinh.net.png,0)
print(type(img))
print(img.shape)
plt.imshow(img, cmap='gray')
plt.show()
